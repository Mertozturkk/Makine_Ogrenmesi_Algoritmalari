# %% [markdown]
# ![mnist.png](attachment:mnist.png)

# %% [markdown]
# https://towardsdatascience.com/improving-accuracy-on-mnist-using-data-augmentation-b5c38eb5a903

# %%
import numpy as np
import gzip
import struct

def load_digits(file_name):    
    with gzip.open(file_name, 'rb') as f:
        # magic_number = struct.unpack('>I', f.read(4))
        # number_of_images = struct.unpack('>I', f.read(4))
        # number_of_rows = struct.unpack('>I', f.read(4))
        # number_of_columns = struct.unpack('>I', f.read(4))
        _cache, img_n, rows, cols = struct.unpack('>IIII', f.read(16))
        all_images = np.frombuffer(f.read(), dtype=np.uint8)
        return all_images.reshape(img_n, rows * cols)
    
    
def add_bias(X):
    return np.insert(X, 0, 1, axis=1)

def get_labels(file_name):
    with gzip.open(file_name, 'rb') as f:
        f.read(8)
        all_labels = f.read()
        return np.frombuffer(all_labels, dtype=np.uint8).reshape(-1,1)

# %%
X_train = add_bias(load_digits("train-images-idx3-ubyte.gz"))
X_test = add_bias(load_digits("t10k-images-idx3-ubyte.gz"))

# %%
import matplotlib.pyplot as plt
import random

X = load_digits("train-images-idx3-ubyte.gz")
Y = get_labels("train-labels-idx1-ubyte.gz")

fig = plt.figure(figsize=(24,8))
for i in range(6*12):
    ax = fig.add_subplot(6, 12, i + 1)
    ax.axis('off')
    index = random.randint(0, X.shape[0])
    ax.set_title(Y[index,0], fontsize="16")
    ax.imshow(X[index].reshape((28,28)), cmap="Greys")
plt.show()

# %%
Y[:5]
# Out:
# array([['M'],
#        ['R'],
#        ['R'],
#        ['M'],
#        ['R']], dtype='<U6')

# %%
def encoding(Y):
    number_of_observations = Y.shape[0]
    number_of_classes = 2 
    one_hot_encoded_Y = np.zeros((number_of_observations, number_of_classes))
    for i in range(number_of_observations):
        one_hot_encoded_Y[i][Y[i]]=1
        
    return one_hot_encoded_Y

# %%
X_train = add_bias(load_digits("train-images-idx3-ubyte.gz"))
Y_train = encoding(get_labels("train-labels-idx1-ubyte.gz"))
X_test = add_bias(load_digits("t10k-images-idx3-ubyte.gz"))
Y_test = get_labels("t10k-labels-idx1-ubyte.gz")
Y_test_encoded = encoding(get_labels("t10k-labels-idx1-ubyte.gz"))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-60-9f6bb2a6f192> in <module>
#       1 X_train = add_bias(load_digits("train-images-idx3-ubyte.gz"))
# ----> 2 Y_train = encoding(get_labels("train-labels-idx1-ubyte.gz"))
#       3 X_test = add_bias(load_digits("t10k-images-idx3-ubyte.gz"))
#       4 Y_test = get_labels("t10k-labels-idx1-ubyte.gz")
#       5 Y_test_encoded = encoding(get_labels("t10k-labels-idx1-ubyte.gz"))
#
# <ipython-input-59-86331cd3a608> in encoding(Y)
#       4     one_hot_encoded_Y = np.zeros((number_of_observations, number_of_classes))
#       5     for i in range(number_of_observations):
# ----> 6         one_hot_encoded_Y[i][Y[i]]=1
#       7
#       8     return one_hot_encoded_Y
#
# IndexError: index 5 is out of bounds for axis 0 with size 2

# %%
from logistic_model import LogisticRegression


model = LogisticRegression(X_train.shape[1], X_train.shape[0])

model.fit(X_train, Y_train, X_test, Y_test, 10000, 1e-5)
# Out:
# Training..
# Iter : 0 Validation Accuracy: 0.90420 Validation Loss: 0.85902
# Iter : 91 Validation Accuracy: 0.98050 Validation Loss: 0.05876
# Iter : 92 Validation Accuracy: 0.98060 Validation Loss: 0.05863
# Iter : 93 Validation Accuracy: 0.98060 Validation Loss: 0.05850
# Iter : 94 Validation Accuracy: 0.98060 Validation Loss: 0.05838
# Iter : 95 Validation Accuracy: 0.98060 Validation Loss: 0.05826
# Iter : 96 Validation Accuracy: 0.98070 Validation Loss: 0.05814
# Iter : 97 Validation Accuracy: 0.98070 Validation Loss: 0.05802
# Iter : 98 Validation Accuracy: 0.98070 Validation Loss: 0.05790
# Iter : 99 Validation Accuracy: 0.98070 Validation Loss: 0.05779
# Iter : 100 Validation Accuracy: 0.98070 Validation Loss: 0.05768
# Iter : 101 Validation Accuracy: 0.98070 Validation Loss: 0.05756
# Iter : 102 Validation Accuracy: 0.98070 Validation Loss: 0.05746
# Iter : 103 Validation Accuracy: 0.98070 Validation Loss: 0.05735
# Iter : 104 Validation Accuracy: 0.98090 Validation Loss: 0.05724
# Training process has been completed!

# %%
model.plot()

# %%
plt.imshow(X_test[2599,1:].reshape((28,28)),cmap="Greys")

# %%
Y_test[2598]
# Out:
# array([0])

# %%
def magic_sigmoid(z):
    return 1/(1 + np.exp(-z))

def forward_pass(X, w):
    return magic_sigmoid(np.matmul(X, w))

def predict(X, w):
        return np.argmax(forward_pass(X, w))

# %%
predict(X_test[2598], model.weights)
# Out:
# 0

# %%
import csv
import numpy as np

with open("sonar.all-data", 'r') as f:
    data = list(csv.reader(f, delimiter=","))

data = np.array(data)

# %%
data[:5]
# Out:
# array([['0.0200', '0.0371', '0.0428', '0.0207', '0.0954', '0.0986',
#         '0.1539', '0.1601', '0.3109', '0.2111', '0.1609', '0.1582',
#         '0.2238', '0.0645', '0.0660', '0.2273', '0.3100', '0.2999',
#         '0.5078', '0.4797', '0.5783', '0.5071', '0.4328', '0.5550',
#         '0.6711', '0.6415', '0.7104', '0.8080', '0.6791', '0.3857',
#         '0.1307', '0.2604', '0.5121', '0.7547', '0.8537', '0.8507',
#         '0.6692', '0.6097', '0.4943', '0.2744', '0.0510', '0.2834',
#         '0.2825', '0.4256', '0.2641', '0.1386', '0.1051', '0.1343',
#         '0.0383', '0.0324', '0.0232', '0.0027', '0.0065', '0.0159',
#         '0.0072', '0.0167', '0.0180', '0.0084', '0.0090', '0.0032', 'R'],
#        ['0.0453', '0.0523', '0.0843', '0.0689', '0.1183', '0.2583',
#         '0.2156', '0.3481', '0.3337', '0.2872', '0.4918', '0.6552',
#         '0.6919', '0.7797', '0.7464', '0.9444', '1.0000', '0.8874',
#         '0.8024', '0.7818', '0.5212', '0.4052', '0.3957', '0.3914',
#         '0.3250', '0.3200', '0.3271', '0.2767', '0.4423', '0.2028',
#         '0.3788', '0.2947', '0.1984', '0.2341', '0.1306', '0.4182',
#         '0.3835', '0.1057', '0.1840', '0.1970', '0.1674', '0.0583',
#         '0.1401', '0.1628', '0.0621', '0.0203', '0.0530', '0.0742',
#         '0.0409', '0.0061', '0.0125', '0.0084', '0.0089', '0.0048',
#         '0.0094', '0.0191', '0.0140', '0.0049', '0.0052', '0.0044', 'R'],
#        ['0.0262', '0.0582', '0.1099', '0.1083', '0.0974', '0.2280',
#         2.300e-03],
#        [1.000e+00, 5.990e-02, 4.740e-02, 4.980e-02, 3.870e-02, 1.026e-01,
#         7.730e-02, 8.530e-02, 4.470e-02, 1.094e-01, 3.510e-02, 1.582e-01,
#         2.023e-01, 2.268e-01, 2.829e-01, 3.819e-01, 4.665e-01, 6.687e-01,
#         8.647e-01, 9.361e-01, 9.367e-01, 9.144e-01, 9.162e-01, 9.311e-01,
#         8.604e-01, 7.327e-01, 5.763e-01, 4.162e-01, 4.113e-01, 4.146e-01,
#         3.149e-01, 2.936e-01, 3.169e-01, 3.149e-01, 4.132e-01, 3.994e-01,
#         4.195e-01, 4.532e-01, 4.419e-01, 4.737e-01, 3.431e-01, 3.194e-01,
#         3.370e-01, 2.493e-01, 2.650e-01, 1.748e-01, 9.320e-02, 5.300e-02,
#         8.100e-03, 3.420e-02, 1.370e-02, 2.800e-03, 1.300e-03, 5.000e-04,
#         2.270e-02, 2.090e-02, 8.100e-03, 1.170e-02, 1.140e-02, 1.120e-02,
#         1.000e-02],
#        [1.000e+00, 3.650e-02, 1.632e-01, 1.636e-01, 1.421e-01, 1.130e-01,
#         1.306e-01, 2.112e-01, 2.268e-01, 2.992e-01, 3.735e-01, 3.042e-01,
#         3.870e-02, 2.679e-01, 5.397e-01, 6.204e-01, 7.257e-01, 8.350e-01,
#         6.888e-01, 4.450e-01, 3.921e-01, 5.605e-01, 7.545e-01, 8.311e-01,
#         1.000e+00, 8.762e-01, 7.092e-01, 7.009e-01, 5.014e-01, 3.942e-01,
#         4.456e-01, 4.072e-01, 7.730e-02, 1.423e-01, 4.010e-02, 3.597e-01,
#         6.847e-01, 7.076e-01, 3.597e-01, 6.120e-02, 3.027e-01, 3.966e-01,
#         3.868e-01, 2.380e-01, 2.059e-01, 2.288e-01, 1.704e-01, 1.587e-01,
#         1.792e-01, 1.022e-01, 1.510e-02, 2.230e-02, 1.100e-02, 7.100e-03,
#         2.050e-02, 1.640e-02, 6.300e-03, 7.800e-03, 9.400e-03, 1.100e-02,
#         6.800e-03]], dtype=float32)

# %%
Y = data_bias[:, -1].reshape(-1,1)
Y_boolean = (Y=='M').astype(np.int)
Y[:5], Y_boolean[:5]
# Out:
# (array([['M'],
#         ['R'],
#         ['R'],
#         ['M'],
#         ['R']], dtype='<U6'),
#  array([[1],
#         [0],
#         [0],
#         [1],
#         [0]]))

# %%
X_train, X_test = np.vsplit(X, [166])
Y_train, Y_test = np.vsplit(Y_boolean, [166])

# %%
X_train.shape, X_test.shape
# Out:
# ((166, 61), (42, 61))

# %%
Y_train = encoding(Y_train)
Y_test_encoded = encoding(Y_test)

# %%
Y_train[:5]
# Out:
# array([[0],
#        [0],
#        [0],
#        [0],
#        [0]])

# %%
from logistic_model import LogisticRegression

model_2 = LogisticRegression(X_train.shape[1], X_train.shape[0])
model_2.fit(X_train, Y_train, X_test, Y_test, Y_test_encoded, 10000, 0.1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-ebca092cfd72> in <module>
#       2
#       3 model_2 = LogisticRegression(X_train.shape[1], X_train.shape[0])
# ----> 4 model_2.fit(X_train, Y_train, X_test, Y_test, Y_test_encoded, 10000, 0.1)
#
# TypeError: fit() takes 7 positional arguments but 8 were given
